# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %%
from xml.etree import ElementTree as ET
from xml.etree.ElementTree import Element
from xml.etree.ElementTree import SubElement

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
users = document_tree.find('users')

# %%
for node in document_tree.getiterator():
    print(node.tag, node.attrib, node.text, node.tail)
# Out:
# mondial {}
#     None
# country {'area': '28750', 'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'capital': 'cty-Albania-Tirane', 'car_code': 'AL'}
#
#
# name {} Albania
#
# population {'measured': 'est.', 'year': '1950'} 1214489
#
# population {'measured': 'est.', 'year': '1960'} 1618829
#
# population {'measured': 'est.', 'year': '1970'} 2138966
#
# population {'measured': 'est.', 'year': '1980'} 2734776
#
# population {'measured': 'est.', 'year': '1990'} 3446882
#
# population {'year': '1997'} 3249136
#
# population {'measured': 'est.', 'year': '2000'} 3304948
#
# population {'measured': 'census', 'year': '2001'} 3069275
#
# population {'measured': 'census', 'year': '2011'} 2800138
#
# population_growth {} 0.3
#
# infant_mortality {} 13.19
#
# gdp_total {} 12800
#
# gdp_agri {} 19.5
#
# gdp_ind {} 12
#
# gdp_serv {} 68.5
#
# inflation {} 1.7
#
# unemployment {} 16.9
#
# indep_date {'from': 'Ottoman Empire'} 1912-11-28
#
# government {} parliamentary democracy
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '95'} Albanian
#
# ethnicgroup {'percentage': '3'} Greek
#
# religion {'percentage': '70'} Muslim
#
# religion {'percentage': '10'} Roman Catholic
#
# religion {'percentage': '20'} Christian Orthodox
#
# language {'percentage': '98.8'} Albanian
#
# language {'percentage': '0.5'} Greek
#
# border {'length': '282', 'country': 'GR'} None
#
# border {'length': '151', 'country': 'MK'} None
#
# border {'length': '172', 'country': 'MNE'} None
#
# border {'length': '112', 'country': 'KOS'} None
#
# city {'id': 'cty-Albania-Tirane', 'country': 'AL'}
#
#
# name {} Tirana
#
# name {} Tirane
#
# latitude {} 41.3
#
# longitude {} 19.8
#
# population {'year': '1987'} 192000
#
# population {'measured': 'estimate', 'year': '1990'} 244153
#
# population {'measured': 'census', 'year': '2011'} 418495
#
# city {'id': 'stadt-Shkoder-AL-AL', 'country': 'AL'}
#
#
# name {} Shkodër
#
# latitude {} 42.2
#
# longitude {} 19.2
#
# population {'year': '1987'} 62000
#
# population {'measured': 'census', 'year': '2011'} 77075
#
# located_at {'lake': 'lake-Skutarisee', 'watertype': 'lake'} None
#
# city {'id': 'stadt-Durres-AL-AL', 'country': 'AL'}
#
#
# name {} Durrës
#
# latitude {} 41.3
#
# longitude {} 19.3
#
# population {'year': '1987'} 60000
#
# population {'measured': 'census', 'year': '2011'} 113249
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'id': 'stadt-Vlore-AL-AL', 'country': 'AL'}
#
#
# name {} Vlorë
#
# latitude {} 40.3
#
# longitude {} 19.3
#
# population {'year': '1987'} 56000
#
# population {'measured': 'census', 'year': '2011'} 79513
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'id': 'stadt-Elbasan-AL-AL', 'country': 'AL'}
#
#
# name {} Elbasan
#
# latitude {} 41.1
#
# longitude {} 20.1
#
# population {'year': '1987'} 53000
#
# population {'measured': 'census', 'year': '2011'} 78703
#
# city {'id': 'stadt-Korce-AL-AL', 'country': 'AL'}
#
#
# name {} Korçë
#
# latitude {} 40.4
#
# longitude {} 20.5
#
# population {'year': '1987'} 52000
#
# population {'measured': 'census', 'year': '2011'} 51152
#
# country {'area': '131940', 'memberships': 'org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC', 'capital': 'cty-Greece-Athens', 'car_code': 'GR'}
#
#
# name {} Greece
#
# localname {} Ελληνική Δημοκρατία
#
# population {'measured': 'census', 'year': '1861'} 1096810
#
# population {'measured': 'census', 'year': '1870'} 1457894
#
# population {'measured': 'census', 'year': '1879'} 1679470
#
# population {'measured': 'census', 'year': '1896'} 2433806
#
# population {'measured': 'census', 'year': '1907'} 2631592
#
# population {'measured': 'census', 'year': '1920'} 5016889
#
# population {'measured': 'census', 'year': '1928'} 6204684
#
# population {'measured': 'census', 'year': '1940'} 7344860
#
# population {'measured': 'census', 'year': '1951'} 7632801
#
# population {'measured': 'census', 'year': '1961'} 8388553
#
# population {'measured': 'census', 'year': '1971'} 8768372
#
# population {'measured': 'census', 'year': '1981'} 9739589
#
# population {'measured': 'census', 'year': '1991'} 10217335
#
# population {'measured': 'census', 'year': '2001'} 10934097
#
# population {'measured': 'census', 'year': '2011'} 10816286
#
# population_growth {} 0.01
#
# infant_mortality {} 4.78
#
# gdp_total {} 243300
#
# gdp_agri {} 3.5
#
# gdp_ind {} 16
#
# gdp_serv {} 80.5
#
# inflation {} -0.8
#
# unemployment {} 27.9
#
# indep_date {'from': 'Ottoman Empire'} 1829-01-01
#
# government {} parliamentary republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '93'} Greek
#
# religion {'percentage': '98'} Christian Orthodox
#
# religion {'percentage': '1.3'} Muslim
#
# language {'percentage': '99'} Greek
#
# border {'length': '282', 'country': 'AL'} None
#
# border {'length': '228', 'country': 'MK'} None
#
# border {'length': '494', 'country': 'BG'} None
#
# border {'length': '206', 'country': 'TR'} None
#
# province {'capital': 'cty-Greece-Komotini', 'id': 'prov-Greece-2', 'country': 'GR'}
#
#
# name {} Anatolikis Makedonias kai Thrakis
#
# localname {} Ανατολικής Μακεδονίας και Θράκης
#
# area {} 14157
#
# population {'measured': 'census', 'year': '1991'} 570197
#
# population {'year': '1994'} 574308
#
# population {'measured': 'census', 'year': '2001'} 607162
#
# population {'measured': 'census', 'year': '2011'} 608182
#
# city {'province': 'prov-Greece-2', 'id': 'cty-Greece-Komotini', 'country': 'GR'}
#
#
# name {} Komotini
#
# city {'province': 'prov-Greece-2', 'id': 'cty-Greece-9', 'country': 'GR'}
#
#
# name {} Kavala
#
# population {'year': '1981'} 56705
#
# population {'measured': 'census', 'year': '1991'} 60187
#
# population {'measured': 'census', 'year': '2001'} 63774
#
# population {'measured': 'census', 'year': '2011'} 58790
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'capital': 'cty-Greece-Athens', 'id': 'prov-Greece-3', 'country': 'GR'}
#
#
# name {} Attikis
#
# localname {} Αττικής
#
# area {} 3808
#
# population {'measured': 'census', 'year': '1991'} 3594817
#
# population {'year': '1994'} 3522769
#
# population {'measured': 'census', 'year': '2001'} 3894573
#
# population {'measured': 'census', 'year': '2011'} 3828434
#
# city {'province': 'prov-Greece-3', 'id': 'cty-Greece-Athens', 'country': 'GR'}
#
#
# name {} Athina
#
# localname {} Αθήνα
#
# latitude {} 38.0
#
# longitude {} 23.75
#
# population {'year': '1981'} 885737
#
# population {'measured': 'census', 'year': '1991'} 816556
#
# population {'measured': 'census', 'year': '2001'} 789166
#
# population {'measured': 'census', 'year': '2011'} 664046
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'province': 'prov-Greece-3', 'id': 'cty-Greece-4', 'country': 'GR'}
#
#
# name {} Peiraias
#
# name {} Piräus
#
# localname {} Πειραιάς
#
# population {'year': '1981'} 196389
#
# population {'measured': 'census', 'year': '1991'} 187399
#
# population {'measured': 'census', 'year': '2001'} 181933
#
# population {'measured': 'census', 'year': '2011'} 163688
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'province': 'prov-Greece-3', 'id': 'cty-Greece-Peristeri', 'country': 'GR'}
#
#
# name {} Peristeri
#
# localname {} Περιστέρι
#
# population {'measured': 'census', 'year': '1991'} 141971
#
# population {'measured': 'census', 'year': '2001'} 146743
#
# population {'measured': 'census', 'year': '2011'} 139981
#
# city {'province': 'prov-Greece-3', 'id': 'cty-Greece-Acharnes', 'country': 'GR'}
#
#
# name {} Acharnes
#
# localname {} Αχαρνές
#
# population {'measured': 'census', 'year': '1991'} 65035
#
# population {'measured': 'census', 'year': '2001'} 82555
#
# population {'measured': 'census', 'year': '2011'} 106943
#
# province {'capital': 'cty-Greece-5', 'id': 'prov-Greece-4', 'country': 'GR'}
#
#
# name {} Dytikis Elladas
#
# localname {} Δυτικής Ελλάδας
#
# area {} 11350
#
# population {'measured': 'census', 'year': '1991'} 695044
#
# population {'year': '1994'} 702027
#
# population {'measured': 'census', 'year': '2001'} 721541
#
# population {'measured': 'census', 'year': '2011'} 679796
#
# city {'province': 'prov-Greece-4', 'id': 'cty-Greece-5', 'country': 'GR'}
#
#
# name {} Patra
#
# name {} Patras
#
# localname {} Πάτρα
#
# population {'year': '1981'} 142163
#
# population {'measured': 'census', 'year': '1991'} 190463
#
# population {'measured': 'census', 'year': '2001'} 210494
#
# population {'measured': 'census', 'year': '2011'} 213984
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'capital': 'cty-Greece-Kozani', 'id': 'prov-Greece-5', 'country': 'GR'}
#
#
# name {} Dytikis Makedonias
#
# localname {} Δυτικής Μακεδονίας
#
# area {} 9451
#
# population {'measured': 'census', 'year': '1991'} 288495
#
# population {'year': '1994'} 292751
#
# population {'measured': 'census', 'year': '2001'} 294317
#
# population {'measured': 'census', 'year': '2011'} 283689
#
# city {'province': 'prov-Greece-5', 'id': 'cty-Greece-Kozani', 'country': 'GR'}
#
#
# name {} Kozani
#
# province {'capital': 'cty-Greece-Korfu', 'id': 'prov-Greece-6', 'country': 'GR'}
#
#
# name {} Ionion Nison
#
# localname {} Ιονίων Νήσων
#
# area {} 2306
#
# population {'measured': 'census', 'year': '1991'} 189338
#
# population {'year': '1994'} 191003
#
# population {'measured': 'census', 'year': '2001'} 209608
#
# population {'measured': 'census', 'year': '2011'} 207855
#
# city {'province': 'prov-Greece-6', 'id': 'cty-Greece-Korfu', 'country': 'GR'}
#
#
# name {} Kerkyra
#
# name {} Korfu
#
# localname {} Κέρκυρας
#
# population {'measured': 'census', 'year': '1991'} 101236
#
# population {'measured': 'census', 'year': '2001'} 108652
#
# population {'measured': 'census', 'year': '2011'} 102071
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Korfu'} None
#
# province {'capital': 'cty-Greece-Ioannina', 'id': 'prov-Greece-7', 'country': 'GR'}
#
#
# name {} Ipeiroy
#
# localname {} Ηπείρου
#
# area {} 9203
#
# population {'measured': 'census', 'year': '1991'} 327176
#
# population {'measured': 'census', 'year': '2001'} 336392
#
# population {'measured': 'census', 'year': '2011'} 336856
#
# city {'province': 'prov-Greece-7', 'id': 'cty-Greece-Ioannina', 'country': 'GR'}
#
#
# name {} Ioannina
#
# localname {} Ιωαννιτών
#
# population {'measured': 'census', 'year': '1991'} 92425
#
# population {'measured': 'census', 'year': '2001'} 103101
#
# population {'measured': 'census', 'year': '2011'} 112486
#
# province {'capital': 'cty-Greece-Thessaloniki', 'id': 'prov-Greece-8', 'country': 'GR'}
#
#
# name {} Kentrikis Makedonias
#
# localname {} Κεντρικής Μακεδονίας
#
# area {} 18810
#
# population {'measured': 'census', 'year': '1991'} 1706338
#
# population {'year': '1994'} 1729581
#
# population {'measured': 'census', 'year': '2001'} 1874597
#
# population {'measured': 'census', 'year': '2011'} 1880297
#
# city {'province': 'prov-Greece-8', 'id': 'cty-Greece-Thessaloniki', 'country': 'GR'}
#
#
# name {} Thessaloniki
#
# localname {} Θεσσαλονίκη
#
# latitude {} 40.6167
#
# longitude {} 22.95
#
# population {'year': '1981'} 406413
#
# population {'measured': 'census', 'year': '1991'} 424220
#
# population {'measured': 'census', 'year': '2001'} 397156
#
# population {'measured': 'census', 'year': '2011'} 325182
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'capital': 'cty-Greece-7', 'id': 'prov-Greece-9', 'country': 'GR'}
#
#
# name {} Kritis
#
# localname {} Κρήτης
#
# area {} 8335
#
# population {'measured': 'census', 'year': '1991'} 536633
#
# population {'year': '1994'} 537183
#
# population {'measured': 'census', 'year': '2001'} 594368
#
# population {'measured': 'census', 'year': '2011'} 623065
#
# city {'province': 'prov-Greece-9', 'id': 'cty-Greece-7', 'country': 'GR'}
#
#
# name {} Iraklio
#
# name {} Iraklion
#
# localname {} Ηράκλειο
#
# population {'year': '1981'} 102398
#
# population {'measured': 'census', 'year': '1991'} 146536
#
# population {'measured': 'census', 'year': '2001'} 163115
#
# population {'measured': 'census', 'year': '2011'} 173993
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Crete'} None
#
# city {'province': 'prov-Greece-9', 'id': 'cty-Greece-Chania', 'country': 'GR'}
#
#
# name {} Chania
#
# localname {} Χανίων
#
# population {'measured': 'census', 'year': '1991'} 83712
#
# population {'measured': 'census', 'year': '2001'} 98202
#
# population {'measured': 'census', 'year': '2011'} 108642
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Crete'} None
#
# province {'capital': 'cty-Greece-Ermoupoli', 'id': 'prov-Greece-10', 'country': 'GR'}
#
#
# name {} Notioy Aigaioy
#
# localname {} Νότιου Αιγαίου
#
# area {} 5285
#
# population {'measured': 'census', 'year': '1991'} 255192
#
# population {'year': '1994'} 262522
#
# population {'measured': 'census', 'year': '2001'} 298462
#
# population {'measured': 'census', 'year': '2011'} 309015
#
# city {'province': 'prov-Greece-10', 'id': 'cty-Greece-Ermoupoli', 'country': 'GR'}
#
#
# name {} Ermoupoli
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Syros'} None
#
# city {'province': 'prov-Greece-10', 'id': 'cty-Greece-Rhodes', 'country': 'GR'}
#
#
# name {} Rhodes
#
# name {} Rhodos
#
# localname {} Ρόδου
#
# population {'measured': 'census', 'year': '1991'} 96159
#
# population {'measured': 'census', 'year': '2001'} 115334
#
# population {'measured': 'census', 'year': '2011'} 115490
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Rhodos'} None
#
# province {'capital': 'cty-Greece-Tripoli', 'id': 'prov-Greece-11', 'country': 'GR'}
#
#
# name {} Peloponnisos
#
# localname {} Πελοποννήσου
#
# area {} 15489
#
# population {'measured': 'census', 'year': '1991'} 573958
#
# population {'measured': 'census', 'year': '2001'} 597622
#
# population {'measured': 'census', 'year': '2011'} 577903
#
# city {'province': 'prov-Greece-11', 'id': 'cty-Greece-Tripoli', 'country': 'GR'}
#
#
# name {} Tripoli
#
# province {'capital': 'cty-Greece-Lamia', 'id': 'prov-Greece-12', 'country': 'GR'}
#
#
# name {} Stereas Elladas
#
# localname {} Στερεάς Ελλάδας
#
# area {} 15549
#
# population {'measured': 'census', 'year': '1991'} 548101
#
# population {'measured': 'census', 'year': '2001'} 558144
#
# population {'measured': 'census', 'year': '2011'} 547390
#
# city {'province': 'prov-Greece-12', 'id': 'cty-Greece-Lamia', 'country': 'GR'}
#
#
# name {} Lamia
#
# localname {} Λαμία
#
# population {'measured': 'census', 'year': '2011'} 75315
#
# city {'province': 'prov-Greece-12', 'id': 'cty-Greece-Chalkida', 'country': 'GR'}
#
#
# name {} Chalkida
#
# name {} Chalkis
#
# localname {} Χαλκιδέων
#
# population {'measured': 'census', 'year': '1991'} 85573
#
# population {'measured': 'census', 'year': '2001'} 92809
#
# population {'measured': 'census', 'year': '2011'} 102223
#
# province {'capital': 'cty-Greece-6', 'id': 'prov-Greece-13', 'country': 'GR'}
#
#
# name {} Thessalias
#
# localname {} Θεσσαλίας
#
# area {} 14036
#
# population {'measured': 'census', 'year': '1991'} 729268
#
# population {'year': '1994'} 731030
#
# population {'measured': 'census', 'year': '2001'} 740115
#
# population {'measured': 'census', 'year': '2011'} 732762
#
# city {'province': 'prov-Greece-13', 'id': 'cty-Greece-6', 'country': 'GR'}
#
#
# name {} Larissa
#
# localname {} Λάρισα
#
# population {'year': '1981'} 102426
#
# population {'measured': 'census', 'year': '1991'} 129429
#
# population {'measured': 'census', 'year': '2001'} 145981
#
# population {'measured': 'census', 'year': '2011'} 162591
#
# city {'province': 'prov-Greece-13', 'id': 'cty-Greece-8', 'country': 'GR'}
#
#
# name {} Volos
#
# localname {} Βόλος
#
# population {'year': '1981'} 71378
#
# population {'measured': 'census', 'year': '1991'} 132917
#
# population {'measured': 'census', 'year': '2001'} 142923
#
# population {'measured': 'census', 'year': '2011'} 144449
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'capital': 'cty-Greece-Mytilini', 'id': 'prov-Greece-14', 'country': 'GR'}
#
#
# name {} Boreioy Aigaioy
#
# localname {} Βορείου Αιγαίου
#
# area {} 3835
#
# population {'measured': 'census', 'year': '1991'} 201363
#
# population {'year': '1994'} 189541
#
# population {'measured': 'census', 'year': '2001'} 205235
#
# population {'measured': 'census', 'year': '2011'} 199231
#
# city {'province': 'prov-Greece-14', 'id': 'cty-Greece-Mytilini', 'country': 'GR'}
#
#
# name {} Mytilini
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Lesbos'} None
#
# province {'capital': 'cty-Greece-Mytilini', 'id': 'prov-Greece-15', 'country': 'GR'}
#
#
# name {} Aghion Oros
#
# localname {} Άγιο Όρος (Αυτοδιοίκητο)
#
# area {} 335
#
# population {'measured': 'census', 'year': '1991'} 1415
#
# population {'measured': 'census', 'year': '2001'} 1961
#
# population {'measured': 'census', 'year': '2011'} 1811
#
# city {'province': 'prov-Greece-15', 'id': 'cty-Greece-Karyes', 'country': 'GR'}
#
#
# name {} Karyes
#
# population {'year': '2014'} 233
#
# country {'area': '25333', 'memberships': 'org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'capital': 'cty-Macedonia-Skopje', 'car_code': 'MK'}
#
#
# name {} Macedonia
#
# localname {} Република Македониjа
#
# population {'measured': 'census', 'year': '1921'} 808724
#
# population {'measured': 'census', 'year': '1931'} 949958
#
# population {'measured': 'census', 'year': '1948'} 1152986
#
# population {'measured': 'census', 'year': '1953'} 1304514
#
# population {'measured': 'census', 'year': '1961'} 1406003
#
# population {'measured': 'census', 'year': '1971'} 1647308
#
# population {'measured': 'census', 'year': '1981'} 1909136
#
# population {'measured': 'census', 'year': '1991'} 2033964
#
# population {'measured': 'census', 'year': '1994'} 1935034
#
# population {'measured': 'census', 'year': '2002'} 2022547
#
# population {'measured': 'estimate', 'year': '2011'} 2059794
#
# population_growth {} 0.21
#
# infant_mortality {} 7.9
#
# gdp_total {} 10650
#
# gdp_agri {} 10.2
#
# gdp_ind {} 27.5
#
# gdp_serv {} 62.3
#
# inflation {} 2.8
#
# unemployment {} 28.6
#
# indep_date {'from': 'Yugoslavia'} 1991-09-17
#
# government {} parliamentary democracy
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '64.2'} Macedonian
#
# ethnicgroup {'percentage': '25.2'} Albanian
#
# ethnicgroup {'percentage': '3.9'} Turkish
#
# ethnicgroup {'percentage': '2.7'} Gypsy
#
# ethnicgroup {'percentage': '1.8'} Serb
#
# religion {'percentage': '64.7'} Christian Orthodox
#
# religion {'percentage': '33.3'} Muslim
#
# religion {'percentage': '0.2'} Roman Catholic
#
# language {'percentage': '66.5'} Macedonian
#
# language {'percentage': '25.1'} Albanian
#
# language {'percentage': '3.5'} Turkish
#
# language {'percentage': '1.9'} Roma
#
# language {'percentage': '1.2'} Serbian
#
# border {'length': '151', 'country': 'AL'} None
#
# border {'length': '228', 'country': 'GR'} None
#
# border {'length': '62', 'country': 'SRB'} None
#
# border {'length': '159', 'country': 'KOS'} None
#
# border {'length': '148', 'country': 'BG'} None
#
# city {'id': 'cty-Macedonia-Skopje', 'country': 'MK'}
#
#
# name {} Skopje
#
# localname {} Град Скопје
#
# latitude {} 42
#
# longitude {} 21.5
#
# population {'measured': 'census', 'year': '2002'} 506926
#
# population {'measured': 'estimate', 'year': '2011'} 514967
#
# city {'id': 'cty-Macedonia-Kumanovo', 'country': 'MK'}
#
#
# name {} Kumanovo
#
# localname {} Град Куманово
#
# latitude {} 42.1
#
# longitude {} 21.7
#
# population {'measured': 'census', 'year': '2002'} 105484
#
# population {'measured': 'estimate', 'year': '2011'} 107745
#
# country {'area': '77474', 'memberships': 'org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-NSG org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMIL org-UNOCI org-MONUSCO org-UNFICYP org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'capital': 'city-Belgrade-SRB-SRB', 'car_code': 'SRB'}
#
#
# name {} Serbia
#
# localname {} Република Србија
#
# population {'measured': 'est.', 'year': '1950'} 6732256
#
# population {'measured': 'est.', 'year': '1960'} 7657958
#
# population {'measured': 'est.', 'year': '1970'} 8236185
#
# population {'measured': 'est.', 'year': '1980'} 9057483
#
# population {'measured': 'est.', 'year': '1990'} 9735429
#
# population {'measured': 'census', 'year': '1991'} 7620531
#
# population {'measured': 'census', 'year': '2002'} 7498001
#
# population {'measured': 'census', 'year': '2011'} 7120666
#
# population_growth {} -0.46
#
# infant_mortality {} 6.16
#
# gdp_total {} 43680
#
# gdp_agri {} 7.9
#
# gdp_ind {} 31.8
#
# gdp_serv {} 60.3
#
# inflation {} 2.2
#
# unemployment {} 20.1
#
# indep_date {'from': 'Yugoslavia'} 1992-04-11
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '82.9'} Serb
#
# ethnicgroup {'percentage': '0.9'} Montenegrin
#
# ethnicgroup {'percentage': '3.9'} Hungarian
#
# ethnicgroup {'percentage': '1.4'} Roma
#
# ethnicgroup {'percentage': '1.8'} Bosniak
#
# ethnicgroup {'percentage': '1.1'} Croat
#
# religion {'percentage': '85'} Christian Orthodox
#
# religion {'percentage': '3.2'} Muslim
#
# religion {'percentage': '5.5'} Roman Catholic
#
# religion {'percentage': '1.1'} Protestant
#
# language {'percentage': '88.3'} Serbian
#
# language {'percentage': '3.8'} Hungarian
#
# language {'percentage': '1.8'} Bosnian
#
# language {'percentage': '1.1'} Roma
#
# border {'length': '151', 'country': 'H'} None
#
# border {'length': '476', 'country': 'RO'} None
#
# border {'length': '318', 'country': 'BG'} None
#
# border {'length': '62', 'country': 'MK'} None
#
# border {'length': '241', 'country': 'HR'} None
#
# border {'length': '357', 'country': 'BIH'} None
#
# border {'length': '124', 'country': 'MNE'} None
#
# border {'length': '352', 'country': 'KOS'} None
#
# city {'id': 'city-Belgrade-SRB-SRB', 'country': 'SRB'}
#
#
# name {} Beograd
#
# localname {} Београд
#
# latitude {} 44.8
#
# longitude {} 20.4667
#
# population {'year': '1987'} 1407073
#
# population {'measured': 'census', 'year': '2002'} 1576124
#
# population {'measured': 'census', 'year': '2011'} 1639121
#
# located_at {'watertype': 'river', 'river': 'river-Donau'} None
#
# located_at {'watertype': 'river', 'river': 'river-Save'} None
#
# city {'id': 'city-NoviSad-SRB-SRB', 'country': 'SRB'}
#
#
# name {} Novi Sad
#
# localname {} Нови Сад
#
# population {'measured': 'census', 'year': '2002'} 299294
#
# population {'measured': 'census', 'year': '2011'} 335701
#
# located_at {'watertype': 'river', 'river': 'river-Donau'} None
#
# city {'id': 'city-Nis-SRB-SRB', 'country': 'SRB'}
#
#
# name {} Niš
#
# localname {} Ниш
#
# population {'measured': 'census', 'year': '2002'} 250518
#
# population {'measured': 'census', 'year': '2011'} 257867
#
# located_at {'watertype': 'river', 'river': 'river-SouthernMorava'} None
#
# country {'area': '14026', 'memberships': 'org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-OSCE org-OPCW org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNMIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'capital': 'city-Podgorica-MNE-MNE', 'car_code': 'MNE'}
#
#
# name {} Montenegro
#
# localname {} Црна Гора
#
# population {'measured': 'census', 'year': '1921'} 311341
#
# population {'measured': 'census', 'year': '1931'} 360044
#
# population {'measured': 'census', 'year': '1948'} 377189
#
# population {'measured': 'census', 'year': '1953'} 419873
#
# population {'measured': 'census', 'year': '1961'} 471894
#
# population {'measured': 'census', 'year': '1971'} 529604
#
# population {'measured': 'census', 'year': '1981'} 584310
#
# population {'measured': 'census', 'year': '1991'} 615035
#
# population {'measured': 'census', 'year': '2003'} 620145
#
# population {'measured': 'census', 'year': '2011'} 620029
#
# population_growth {} -0.49
#
# gdp_total {} 4518
#
# gdp_agri {} 0.8
#
# gdp_ind {} 11.3
#
# gdp_serv {} 87.9
#
# inflation {} 4
#
# unemployment {} 19.1
#
# indep_date {'from': 'SRB'} 2006-06-03
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '43'} Montenegrin
#
# ethnicgroup {'percentage': '32'} Serb
#
# ethnicgroup {'percentage': '8'} Bosniak
#
# ethnicgroup {'percentage': '5'} Albanian
#
# religion {'percentage': '74.2'} Christian Orthodox
#
# religion {'percentage': '17.7'} Muslim
#
# religion {'percentage': '3.5'} Roman Catholic
#
# language {'percentage': '63.6'} Serbian
#
# language {'percentage': '22'} Montenegrin
#
# language {'percentage': '5.5'} Bosnian
#
# language {'percentage': '5.3'} Albanian
#
# border {'length': '25', 'country': 'HR'} None
#
# border {'length': '124', 'country': 'SRB'} None
#
# border {'length': '249', 'country': 'BIH'} None
#
# border {'length': '172', 'country': 'AL'} None
#
# border {'length': '79', 'country': 'KOS'} None
#
# city {'id': 'city-Podgorica-MNE-MNE', 'country': 'MNE'}
#
#
# name {} Podgorica
#
# latitude {} 42.26
#
# longitude {} 19.16
#
# population {'measured': 'census', 'year': '2003'} 136473
#
# population {'measured': 'census', 'year': '2011'} 150977
#
# located_at {'watertype': 'river', 'river': 'river-Moraca'} None
#
# country {'area': '10887', 'memberships': 'org-CD org-EBRD org-IBRD org-IDA org-IFC org-IMF org-ITUC', 'capital': 'city-Pristina-KOS-KOS', 'car_code': 'KOS'}
#
#
# name {} Kosovo
#
# localname {} Republika e Kosovës
#
# population {'measured': 'census', 'year': '1981'} 1584440
#
# population {'measured': 'census', 'year': '1991'} 1956196
#
# population {'measured': 'census', 'year': '2011'} 1733872
#
# gdp_total {} 7150
#
# gdp_agri {} 12.9
#
# gdp_ind {} 22.6
#
# gdp_serv {} 64.5
#
# inflation {} 1.8
#
# unemployment {} 30.9
#
# indep_date {'from': 'SRB'} 2008-02-17
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '92'} Albanian
#
# ethnicgroup {'percentage': '5'} Serbian
#
# religion {'percentage': '90'} Muslim
#
# language {'percentage': '92'} Albanian
#
# language {'percentage': '5'} Serbian
#
# border {'length': '79', 'country': 'MNE'} None
#
# border {'length': '352', 'country': 'SRB'} None
#
# border {'length': '159', 'country': 'MK'} None
#
# border {'length': '112', 'country': 'AL'} None
#
# city {'id': 'city-Pristina-KOS-KOS', 'country': 'KOS'}
#
#
# name {} Prishtine
#
# name {} Pristina
#
# latitude {} 42.40
#
# longitude {} 21.10
#
# population {'measured': 'census', 'year': '1981'} 148090
#
# population {'measured': 'census', 'year': '1991'} 199654
#
# population {'measured': 'census', 'year': '2011'} 198214
#
# country {'area': '450', 'memberships': 'org-CE org-FAO org-IPU org-ICC org-ICAO org-ICCt org-Interpol org-IFRCS org-IOC org-OIF org-ITU org-OSCE org-OPCW org-UN org-UNCTAD org-UNESCO org-WCO org-WHO org-WIPO org-UNWTO org-WTO', 'capital': 'cty-Andorra-Andorra-la-Vella', 'car_code': 'AND'}
#
#
#
# name {} Andorra
#
# localname {} Principat d’Andorra
#
# population {'measured': 'est.', 'year': '1950'} 6197
#
# population {'measured': 'est.', 'year': '1960'} 13414
#
# population {'measured': 'est.', 'year': '1970'} 24279
#
# population {'measured': 'est.', 'year': '1980'} 36063
#
# population {'measured': 'census', 'year': '1989'} 46166
#
# population {'measured': 'admin.', 'year': '2001'} 66334
#
# population {'measured': 'admin.', 'year': '2006'} 81222
#
# population {'measured': 'admin.', 'year': '2011'} 78115
#
# population_growth {} 0.17
#
# infant_mortality {} 3.69
#
# gdp_total {} 4800
#
# gdp_agri {} 14
#
# gdp_ind {} 79
#
# gdp_serv {} 6
#
# inflation {} 1.1
#
# unemployment {} 4
#
# indep_date {} 1278-09-08
#
# government {} parliamentary democracy that retains as its chiefs of state a co-principality
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '43'} Spanish
#
# ethnicgroup {'percentage': '33'} Andorran
#
# ethnicgroup {'percentage': '11'} Portuguese
#
# ethnicgroup {'percentage': '2'} French
#
# ethnicgroup {'percentage': '5'} African
#
# religion {'percentage': '95'} Roman Catholic
#
# language {'percentage': '44'} Catalan
#
# language {'percentage': '33'} Spanish
#
# language {'percentage': '2'} Galician
#
# language {'percentage': '11'} Portuguese
#
# language {'percentage': '7'} French
#
# border {'length': '60', 'country': 'F'} None
#
# border {'length': '65', 'country': 'E'} None
#
# city {'id': 'cty-Andorra-Andorra-la-Vella', 'country': 'AND'}
#
#
# name {} Andorra la Vella
#
# latitude {} 42.3
#
# longitude {} 1.3
#
# population {'year': '1987'} 15600
#
# population {'measured': 'admin.', 'year': '2001'} 20787
#
# population {'measured': 'admin.', 'year': '2011'} 22256

# %%
for node in document_tree.getchildren():
    print(node.tag, node.attrib, node.text, node.tail)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9dfbe12827e5> in <module>()
# ----> 1 for node in document_tree.getchildren():
#       2     print(node.tag, node.attrib, node.text, node.tail)
#
# AttributeError: 'ElementTree' object has no attribute 'getchildren'

# %%
# print names of all countries
for child in document_tree.getroot():
    print(child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print('* ' + element.find('name').text + ':',)
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print(capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
root = document.getroot()

# %%
for child in document.getroot():
    print(child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra
# France
# Spain
# Austria
# Czech Republic
# Germany
# Hungary
# Italy
# Liechtenstein
# Slovakia
# Slovenia
# Switzerland
# Belarus
# Latvia
# Lithuania
# Poland
# Ukraine
# Russia
# Belgium
# Luxembourg
# Netherlands
# Bosnia and Herzegovina
# Croatia
# Bulgaria
# Romania
# Turkey
# Denmark
# Estonia
# Faroe Islands
# Finland
# Norway
# Sweden
# Monaco
# Gibraltar
# Guernsey
# Holy See
# Ceuta
# Melilla
# Iceland
# Ireland
# San Marino
# Jersey
# Malta
# Isle of Man
# Moldova
# Portugal
# Svalbard
# United Kingdom
# Afghanistan
# China
# Iran
# Pakistan
# Tajikistan
# Turkmenistan
# Uzbekistan
# Armenia
# Georgia
# Azerbaijan
# Bahrain
# Bangladesh
# Myanmar
# India
# Bhutan
# Brunei
# Malaysia
# Laos
# Thailand
# Cambodia
# Vietnam
# Kazakhstan
# North Korea
# Kyrgyzstan
# Hong Kong
# Macao
# Mongolia
# Nepal
# Christmas Island
# Cocos Islands
# Cyprus
# Gaza Strip
# Israel
# Egypt
# Indonesia
# Timor-Leste
# Papua New Guinea
# Iraq
# Jordan
# Kuwait
# Saudi Arabia
# Syria
# Lebanon
# West Bank
# Japan
# South Korea
# Maldives
# Oman
# United Arab Emirates
# Yemen
# Philippines
# Qatar
# Singapore
# Sri Lanka
# Taiwan
# Anguilla
# Antigua and Barbuda
# Aruba
# Bahamas
# Barbados
# Belize
# Guatemala
# Mexico
# Bermuda
# British Virgin Islands
# Canada
# United States
# Cayman Islands
# Costa Rica
# Nicaragua
# Panama
# Cuba
# Dominica
# Dominican Republic
# Haiti
# El Salvador
# Honduras
# Greenland
# Grenada
# Guadeloupe
# Jamaica
# Martinique
# Montserrat
# Curacao
# Sint Maarten
# Saint Martin
# Saint Barthelemy
# Colombia
# Puerto Rico
# Saint Kitts and Nevis
# Saint Lucia
# Saint Pierre and Miquelon
# Saint Vincent and the Grenadines
# Trinidad and Tobago
# Turks and Caicos Islands
# Chubu Centrair Intl
# Nagasaki
# Kobe
# Narita Intl
# Yamaguchi Ube
# Matsuyama
# Mt. Fuji Shizuoka Airport
# Jersey
# Queen Alia Intl
# Semipalatinsk
# Uralsk
# Atyrau
# Aktau
# Zhezkazgan Airport
# Kostanay West Airport
# Ust Kamenogorsk Airport
# Shymkent
# Aktyubinsk
# Almaty
# Astana Intl
# Sary-Arka
# Pavlodar
# Kzylorda
# Malindi Airport
# Mombasa Moi Intl
# Jomo Kenyatta International
# Nairobi Wilson
# Kisumu
# Eldoret Intl
# Bonriki Intl
# Kuwait Intl
# Manas
# Osh
# Wattay Intl
# Riga Intl
# Rafic Hariri Intl
# Moshoeshoe I Intl
# Monrovia Roberts Intl
# Benina
# Misratah Airport
# Tripoli Intl
# Kaunas Intl
# Vilnius Intl
# Luxembourg
# Macao Intl
# Skopje
# Arrachart
# Toliara
# Ivato
# Chileka Intl
# Kamuzu Intl
# Penang Intl
# Sultan Mahmud
# Sandakan
# Kota Kinabalu Intl
# Sultan Ismail
# Kuching Intl
# Sultan Azlan Shah
# Sultan Ismail Petra
# Sultan Abdul Aziz Shah Intl
# Kuantan
# Kuala Lumpur Intl
# Labuan
# Male Intl
# Senou
# Luqa
# Marshall Islands Intl
# Le Lamentin
# Nouakchott
# Nouadhibou
# Sir Seewoosagur Ramgoolam Intl
# Dzaoudzi Pamandzi
# General Servando Canales Intl
# Ingeniero Alberto Acuna Ongay Intl
# Colima
# Licenciado Y Gen Ignacio Lopez Rayon
# Angel Albino Corzo
# General Abelardo L Rodriguez Intl
# General Heriberto Jara Intl
# Quetzalcoatl Intl
# Licenciado Manuel Crescencio Rejon Int
# General Mariano Escobedo Intl
# Minatitlan
# C P A Carlos Rovirosa Intl
# General Rodolfo Sanchez Taboada Intl
# Hermanos Serdan Intl
# General Leobardo C Ruiz Intl
# Lencero Airport
# Queretaro Intercontinental
# Licenciado Adolfo Lopez Mateos Intl
# Tepic
# General Pedro Jose Mendez Intl
# Ponciano Arriaga Intl
# Chetumal Intl
# General Francisco J Mujica Intl
# Durango Intl
# Don Miguel Hidalgo Y Costilla Intl
# Xoxocotlan Intl
# General Ignacio P Garcia Intl
# General Lucio Blanco Intl
# Licenciado Benito Juarez Intl
# General Rafael Buelna Intl
# General R Fierro Villalobos Intl
# Cancun Intl
# Culiacan Intl
# Tapachula Intl
# General Francisco Javier Mina Intl
# General Manuel Marquez De Leon Intl
# Ciudad Obregon Intl
# Abraham Gonzalez Intl
# Valle Del Fuerte Intl
# Plan De Guadalupe Intl
# Jesus Teran Intl
# Torreon Intl
# General Juan N Alvarez Intl
# Pohnpei Intl
# Chisinau Intl
# Chinggis Khaan Intl
# Podgorica
# John A. Osborne
# Angads
# Inezgane
# Ibn Batouta
# Menara
# Mohammed V Intl
# Cherif El Idrissi
# Sale
# Saiss
# Chimoio Airport
# Nampula
# Tete Chingodzi
# Beira
# Quelimane
# Inhambane
# Pemba
# Maputo
# Lichinga
# Windhoek Hosea Kutako International Airport
# Birmingham Intl
# Bismarck Municipal Airport
# Billings Logan International Airport
# Tulsa Intl
# Tucson Intl
# Reno Tahoe Intl
# Buffalo Niagara Intl
# Hartsfield Jackson Atlanta Intl
# Baton Rouge Metro Ryan Fld
# Austin Bergstrom Intl
# Mc Ghee Tyson
# Baltimore Washington Intl
# Akron Canton Regional Airport
# Lehigh Valley Intl
# Abilene Rgnl
# Alexandria Intl
# Tallahassee Rgnl
# Waco Rgnl
# Albuquerque International Sunport
# San Diego Intl
# San Antonio Intl
# Savannah Hilton Head Intl
# Portland Intl Jetport
# Theodore Francis Green State
# Indianapolis Intl
# Washington Dulles Intl
# George Bush Intcntl Houston
# Wichita Mid Continent
# William P Hobby
# Greater Rochester Intl
# Fort Lauderdale Hollywood Intl
# Eppley Afld
# Portland Intl
# Norfolk Intl
# Chicago Ohare Intl
# Bishop International
# Phoenix Sky Harbor Intl
# Pittsburgh Intl
# Pierre Regional Airport
# Philadelphia Intl
# Helena Rgnl
# Spokane Intl
# Will Rogers World
# Richmond Intl
# John F Kennedy Intl
# Jacksonville Intl
# Jackson Evers Intl
# Santa Fe Muni
# Albert J Ellis
# Metropolitan Oakland Intl
# Juneau Intl
# Ted Stevens Anchorage Intl
# Honolulu Intl
# Hilo Intl
# Lanai
# Molokai
# Kahului
# Carrasco Intl
# Bukhara
# Urgench Airport
# Termez Airport
# Yuzhny
# Nukus Airport
# Fergana Airport
# Samarkand
# Port Vila Bauerfield
# General Manuel Carlos Piar
# General Jose Antonio Anzoategui Intl
# Casique Aramare
# Barinas
# Barquisimeto Intl
# La Chinita Intl
# Arturo Michelena Intl
# Maturin
# Simon Bolivar Intl
# Rach Gia
# Vinh Airport
# Tansonnhat Intl
# Noibai Intl
# Cat Bi International Airport
# Tra Noc Airport
# Nha Trang
# Cyril E King
# Wallis
# Hassan I Airport
# Sanaa Intl
# Hodeidah Intl
# Taiz Intl
# Aden Intl
# Livingstone
# Ndola
# Lusaka Intl
# J M Nkomo Intl
# Harare Intl

# %%
for element in document.iterfind('country'):
    print('* ' + element.find('name').text + ':',)
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print(capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella
# * France:
# Strasbourg, Mulhouse, Bordeaux, Clermont-Ferrand, Caen, Rennes, Brest, Dijon, Orléans, Tours, Reims, Chalons en Champagne, Ajaccio, Besançon, Rouen, Le Havre, Paris, Boulogne-Billancourt, Argenteuil, Montreuil, Saint-Paul, Montpellier, Nîmes, Perpignan, Limoges, Metz, Nancy, Toulouse, Lille, Nantes, Angers, Le Mans, Amiens, Poitiers, Marseille, Nice, Toulon, Aix-en-Provence, Lyon, Grenoble, Saint-Étienne, Villeurbanne
# * Spain:
# Sevilla, Almería, Cádiz, Córdoba, Granada, Huelva, Málaga, Jerez de la Frontera, Jaén, Algeciras, Marbella, Dos Hermanas, Zaragoza, Oviedo, Gijón, Palma de Mallorca, Vitoria-Gasteiz, Bilbao, Barakaldo, Donostia, Santa Cruz de Tenerife, San Cristóbal de La Laguna, Las Palmas de Gran Canaria, Telde, Santander, Valladolid, Burg
amonu, Kayseri, Kirikkale, Kirklareli, Luleburgaz, Kirsehir, Kocaeli, Gebze, Konya, Kütahya, Malatya, Manisa, Mardin, Kızıltepe, Mugla, Mus, Nevsehir, Nigde, Ordu, Rize, Sakarya, Samsun, Şanlıurfa, Siirt, Sinop, Sirnak, Sivas, Tekirdag, Çorlu, Tokat, Trabzon, Tunceli, Usak, Van, Yozgat, Zonguldak, Bartin, Karabük, Ardahan, Iğdır, Yalova, Kilis, Duzce, Osmaniye
# * Denmark:
# Aalborg, Viborg, Århus, Randers, Vejle, Odense, Esbjerg, Hilleroed, København, Soroe
# * Estonia:
# Tallinn, Tartu
# * Faroe Islands:
# Tórshavn
# * Finland:
# Mariehamn, Tampere, Lahti, Hämeenlinna, Kuopio, Lappeenranta, Kotka, Rovaniemi, Mikkeli, Jyväskylä, Joensuu, Oulu, Pori, Turku, Helsinki, Espoo, Vaasa
# * Norway:
# Oslo, Sandvika, Moss, Hamar, Lillehammer, Drammen, Tonsberg, Skien, Arendal, Kristiansand, Stavanger, Bergen, Hermannsverk, Molde, Trondheim, Steinkjer, Svolvaer, Narvik, Bodoe, Tromsø, Hammerfest, Vadsoe
# * Sweden:
# Göteborg, Vanersborg, Mariestad, Borås, Karlskrona, Gävle, Visby, Halmstad, Ostersund, Jönköping, Kalmar, Falun, Malmö, Helsingborg, Kristianstad, Lund, Växjö, Lulea, Jokkmokk, Örebro, Linköping, Norrköping, Nykoping, Eskilstuna, Stockholm, Huddinge, Uppsala, Karlstad, Umeå, Harnosand, Västerås
# * Monaco:
# Monaco
# * Gibraltar:
# Gibraltar
# * Guernsey:
# Saint Peter Port
# * Holy See:
# Vatican City
# * Ceuta:
# Ceuta
# * Melilla:
# Melilla
# * Iceland:
# Reykjavik, Keflavik, Hafnarfjordur, Akureyri
# * Ireland:
# Dublin, Cork, Galway, Limerick
# * San Marino:
# San Marino
# * Jersey:
# Saint Helier
# * Malta:
# Valletta, Victoria
# * Isle of Man:
# Douglas
# * Moldova:
# Chişinău, Tiraspol, Bălţi
# * Portugal:
# Aveiro, Beja, Braga, Braganca, Castelo Branco, Coimbra, Evora, Faro, Guarda, Leiria, Lisboa, Amadora, Barreiro, Almada, Portalegre, Oporto, Vila Nova de Gaia, Santarem, Setúbal, Viana do Castelo, Vila Real, Viseu, Ponta Delgada, Funchal
# * Svalbard:
# Longyearbyen
# * United Kingdom:
# Newcastle upon Tyne, Sunderland, Gateshead, Middlesbrough, Manchester, Wigan, Stockport, Bolton, Salford, Oldham, Rochdale, Warrington, Blackpool, Blackburn, Liverpool, Birkenhead, St Helens, Preston, Leeds, Wakefield, Bradford, Huddersfield, Sheffield, Doncaster, Rotherham, York, Kingston upon Hull, Nottingham, Northampton, Leicester, Derby, Lincoln, Birmingham, Coventry, Wolverhampton, Solihull, Stoke-on-Trent, Worcester, Sutton Coldfield, Telford, Cambridge, Peterborough, Ipswich, Chelmsford, Watford, Southend-on-Sea, Basildon, Colchester, Norwich, Luton, London, Southampton, Portsmouth, Basingstoke, Milton Keynes, High Wycombe, Brighton and Hove, Maidstone, Oxford, Reading, Slough, Eastbourne, Gillingham, Crawley, Worthing, Woking, Bristol, Plymouth, Exeter, Bournemouth, Poole, Cheltenham, Gloucester, Swindon, Edinburgh, Glasgow, Aberdeen, Dundee, Kirkwall, Lerwick, Cardiff, Swansea, Newport, Belfast
# Kathmandu, Pokhara, Lalitpur, Biratnagar
# * Christmas Island:
# Flying Fish Cove
# * Cocos Islands:
# West Island
# * Cyprus:
# Lefkosia, Larnaka, Lemesos
# * Gaza Strip:
# Gaza
# * Israel:
# Yerushalayim, Ramla, Rishon LeZiyyon, Petah Tiqwa, Haifa, Nazareth, Tel Aviv-Yafo, Be'er Sheva, Ashdod
# * Egypt:
# Hurghada, Marsa Matruh, Damanhur, Kafr ad Dawwar, Al Mansurah, Tanta, Al Mahallah al Kubra, Al Isma'iliyah, Shibin al Kum, Banha, Shubra al Khimah, Az Zaqaziq, Aswan, Asyut, Bani Suwayf, Al Fayyum, Al Jizah, Al Minya, Qina, Al Uqsur, Suhaj, Bur Sa'id, Al Iskandariyah, Al Qahirah, As Suways
# * Indonesia:
# Banda Aceh, Medan, Pematang Siantar, Binjai, Padang, Pekanbaru, Dumai, Jambi, Palembang, Lubuk Linggau, Bengkulu, Bandar Lampung, Pangkal Pinang, Tanjungpinang, Batam, Jakarta, Bandung, Bogor, Cirebon, Sukabumi, Bekasi, Depok, Tasikmalaya, Cimahi, Semarang, Surakarta, Pekalongan, Tegal, Yogyakarta, Surabaya, Malang, Probolinggo, Kediri, Serang, Tangerang, Tangerang Selatan, Cilegon, Denpasar, Mataram, Kupang, Pontianak, Palangkaraya, Bandjarmasin, Samarinda, Balikpapan, Manado, Palu, Makassar, Kendari, Gorontalo, Mamuju, Ambon, Ternate, Manokwari, Jayapura
# * Timor-Leste:
# Dili
# * Papua New Guinea:
# Port Moresby
# * Iraq:
# Ar Ramadi, Al Hillah, Baghdad, Al Basrah, An Nasiriyah, Ba'qubah, Kerbela, Al Amarah, As Samawah, An Najaf, Al Mawsil, Diwaniyah, Samarra, Kirkuk, Al Kut, Duhouk, Erbil, As Sulaymaniyah
# * Jordan:
# Amman, Zarqa, Irbid
# * Kuwait:
# Kuwait
# * Saudi Arabia:
# Arar, Al Baha, Sakaka, Al Madinah, Buraydah, Riyadh, Abha, Dammam, Hail, Jazan, Makkah, Jeddah, At Taif, Najran, Tabouk
# * Syria:
# Al Hasakah, Al Qamishl, Al Ladhiqiyah, Al Qunaytirah, Ar Raqqah, As Suwayda', Dar`a, Dayr az Zawr, Dimashq, Halab, Manbij, Hamah, Hims, Idlib, Ma`arrat an Nu`man, Bouapla, Duma, Tartus
# * Lebanon:
# Bayrūt
# * West Bank:
# Ramallah, Nablus, Hebron
# * Japan:
# Sapporo, Hakodate, Aomori, Morioka, Sendai, Akita, Yamagata, Fukushima, Mito, Utsunomiya, Maebashi, Saitama, Kawaguchi, Chiba, Funabashi, Matsudo, Ichikawa, Kashiwa, Tokyo, Hachioji, Machida, Yokohama, Kawasaki, Sagamihara, Yokosuka, Fujisawa, Niigata, Toyama, Kanazawa, Fukui, Kofu, Nagano, Gifu, Shizuoka, Hamamatsu, Nagoya, Toyota, Tsu, Otsu, Kyoto, Osaka, Sakai, Higashiosaka, Hirakata, Kobe, Himeji, Nishinomiya, Amagasaki, Nara, Wakayama, Tottori, Matsue, Okayama, Kurashiki, Hiroshima, Fukuyama, Yamaguchi, Tokushima, Takamatsu, Matsuyama, Kochi, Fukuoka, Kitakyushu, Saga, Nagasaki, Kumamoto, Oita, Miyazaki, Kagoshima, Naha
# * South Korea:
# Seoul, Busan, Daegu, Incheon, Gwangju, Daejeon, Ulsan, Suwon, Seongnam, Jeonju, Changwon, Cheongju, Jinju, Mokpo, Jeju, Gunsan, Chuncheon, Yeosu, Goyang, Yongin, Bucheon, Ansan, Anyang
# * Maldives:
# Male
# * Oman:
# Muscat, As Seeb
# * United Arab Emirates:
# Abu Dhabi, Al Ain, Dubai, Al Sharjah
# * Yemen:
# Sana'a, Aden, Ta'izz, al Hudaydah
# * Philippines:
# San Fernando, Tuguegarao, Cauayan, San Fernando, San Jose Del Monte, Calamba, Antipolo, Legazpi, Iloilo, Bacolod, Cebu, Tacloban, Pagadian, Zamboanga, Cagayan De Oro, Davao, Koronadal, General Santos, Manila, Quezon City, Kalookan, Makati, Pasig, Pasay, Taguig, Valenzuela, Parañaque, Las Piñas, Muntinlupa, Mandaluyong, Marikina, Baguio, Cotabato, Butuan, Calapan
# * Qatar:
# Doha, Al Rayyan
# * Singapore:
# Singapore
# * Sri Lanka:
# Sri Jayawardhanapura Kotte, Colombo
# * Taiwan:
# Taipei, New Taipei, Changhua, Hualien, Pingtung, Taitung, Taoyuan, Jhongli, Chiayi, Keelung, Hsinchu, Kaohsiung, Taichung, Tainan
# * Anguilla:
# The Valley
# * Antigua and Barbuda:
# Saint Johns
# * Aruba:
# Oranjestad
# * Bahamas:
# Nassau
# * Barbados:
# Bridgetown
# * Belize:
# Belmopan, Belize City
# * Guatemala:
# Ciudad de Guatemala, Mixco, Villa Nueva, Cobán
# * Mexico:
# Aguascalientes, Mexicali, Tijuana, Ensenada, La Paz, Campeche, Tuxtla Gutiérrez, Tapachula, Chihuahua, Ciudad Juárez, Saltillo, Torreón, Monclova, Colima, Gómez Palacio, Durango, León, Salamanca, Irapuato, Celaya, Guanajuato, Acapulco, Chilpancingo, Pachuca, Guadalajara, Zapopan, Tlaquepaque, Tonala, Toluca, Ciudad López Mateos, Tlalnepantla, Chimalhuacán, Buenavista, San Pablo, Cuautitlán Izcalli, Nezahualcóyotl, Ecatepec, Naucalpan, Morelia, Uruapan, Zamora de Hidalgo, Cuernavaca, Jiutepec, Cuautla Morelos, Tepic, Monterrey, Guadalupe, San Nicolás de los Garzas, Ciudad Santa Catarina, San Pedro Garza García, Oaxaca, Puebla, Tehuacán, Querétaro, Cancún, Chetumal, San Luis Potosí, Soledad Díez Gutiérrez, Culiacán, Mazatlán, Los Mochis, Hermosillo, Ciudad Obregón, Nogales, Villahermosa, Ciudad Victoria, Tampico, Matamoros, Reynosa, Nuevo Laredo, Ciudad Madero, Tlaxcala, Córdoba, Xalapa-Enríquez, Coatzacoalcos, Poza Rica de Hidalgo, Minatitlán, Orizaba, Veracruz, Boca del Río, Mérida, Zacatecas, Ciudad de México
# * Bermuda:
# * Cayman Islands:
# George Town
# * Costa Rica:
# San José, Alajuela, Cartago, Heredia, Liberia, Puntarenas, Limón
# * Nicaragua:
# Managua, León, Chinandega, Masaya, Granada, Matagalpa, Tipitapa, Jinotega, Estelí
# * Panama:
# Bocas del Toro, Changuinola, Penonomé, Colón, El Porvenir, David, La Palma, Chitre, Las Tablas, Panamá City, San Miguelito, Arraiján, La Chorrera, Santiago, Cirilo Guainora, Chichica
# * Cuba:
# Camagüey, Ciego de Ávila, Cienfuegos, La Habana, Bayamo, Manzanillo, Guantánamo, Holguín, Victoria de las Tunas, Matanzas, Pinar del Río, Sancti Spíritus, Santiago de Cuba, Santa Clara, Nueva Gerona, Artemisa, San José de las Lajas
# * Dominica:
# Roseau
# * Dominican Republic:
# Santo Domingo, Santiago
# * Haiti:
# Port-au-Prince, Carrefour, Delmas, Pétion-Ville, Cité Soleil, Gonaïves, Cap-Haïtien
# * El Salvador:
# San Salvador, Soyapango, Mejicanos, Ciudad Delgado, Apopa, Santa Ana, Santa Tecla, San Miguel
# * Honduras:
# La Ceiba, Tela, Trujillo, Comayagua, Santa Rosa de Copan, San Pedro Sula, Puerto Cortes, Choloma, Choluteca, Danlí, Yuscaran, Tegucigalpa, Siguatepeque, Puerto Lempira, La Esperanza, Roatan, La Paz, Gracias, Ocotepeque, Juticalpa, Santa Barbara, Nacaome, El Progreso, Olanchito, Yoro
# * Greenland:
# Nuuk
# * Grenada:
# Saint George's
# * Guadeloupe:
# Basse-Terre
# * Jamaica:
# Kingston
# * Martinique:
# Fort-de-France
# * Montserrat:
# Plymouth
# * Curacao:
# Willemstad
# * Sint Maarten:
# Philipsburg
# * Saint Martin:
# Marigot
# * Saint Barthelemy:
# Gustavia
# * Colombia:
# Leticia, Medellín, Bello, Itagui, Turbo, Envigado, Apartadó, Arauca, Barranquilla, Soledad, Malambo, Cartagena, Magangué, Tunja, Manizales, Florencia, Yopal, Popayán, Valledupar, Quibdó, Montería, Soacha, Puerto Inirida, Ciénaga, Riohacha, Uribia, San Jose del Guaviare, Neiva, Santa Marta, Villavicencio, Pasto, San Andres de Tumaco, Cúcuta, Mocoa, Armenia, Pereira, Dosquebradas, San Andres, Bogotá, Bucaramanga, Floridablanca, Barrancabermeja, Girón, Sincelejo, Ibagué, Cali, Buenaventura, Palmira, Tuluá, Cartago, Mitu, Puerto Carreno
# * Puerto Rico:
# San Juan, Ponce, Bayamón, Carolina
# * Saint Kitts and Nevis:
# Basseterre
# * Saint Lucia:
# Castries
# * Saint Pierre and Miquelon:
# Saint-Pierre
# * Saint Vincent and the Grenadines:
# Kingstown
# * Trinidad and Tobago:
# Port-of-Spain
# * Turks and Caicos Islands:
# Grand Turk
# * Virgin Islands:
# Charlotte Amalie
# * American Samoa:
# Pago Pago
# * Australia:
# Newcastle, Sydney, Wollongong, Sunshine Coast, Darwin, Brisbane, Gold Coast, Townsville, Cairns, Adelaide, Hobart, Melbourne, Geelong, Perth, Canberra
# * Cook Islands:
# Avarua
# * Fiji:
# Suva
# * French Polynesia:
# Papeete
# * Guam:
# Agana
# * Kiribati:
# Tarawa
# * Marshall Islands:
# Majuro
# * Micronesia:
# Kolonia, Palikir
# * Nauru:
# Yaren
# * New Caledonia:
# Noumea
# * New Zealand:
# Wellington, Auckland, Hamilton, Christchurch, Dunedin
# * Niue:
# Alofi
# * Norfolk Island:
# Kingston
# * Northern Mariana Islands:
# Saipan
# * Palau:
# Koror, Melekeok
# * Pitcairn:
# Adamstown
# * Solomon Islands:
# Honiara
# * Tonga:
# Nukualofa
# * Tuvalu:
# Funafuti
# * Tokelau:
# Fakaofo
# * Vanuatu:
# Port Vila
# * Wallis and Futuna:
# Mata-Utu
# * Samoa:
# Apia
# * Argentina:
# La Plata, San Justo, Morón, Lomas de Zamora, Mar del Plata, Quilmes, Lanús, General San Martín, Avellaneda, San Isidro, Vicente López, Bahía Blanca, San Nicolás de los Arroyos, San Fernando del Valle de Catamarca, Resistencia, Comodoro Rivadavia, Rawson, Córdoba, Río Cuarto, Corrientes, Paraná, Concordia, Formosa, San Salvador de Jujuy, Santa Rosa, La Rioja, Mendoza, Posadas, Neuquén, Viedma, Salta, San Juan, San Luis, Río Gallegos, Santa Fe, Rosario, Santiago del Estero, Ushuaia, San Miguel de Tucumán, Buenos Aires
# * Bolivia:
# La Paz, El Alto, Oruro, Potosí, Santa Cruz de la Sierra, Montero, Trinidad, Cobija, Sucre, Cochabamba, Sacaba, Quillacollo, Tarija
# * Brazil:
# Rio Branco, Maceió, Arapiraca, Macapá, Manaus, Salvador, Feira de Santana, Ilhéus, Vitória da Conquista, Itabuna, Juazeiro, Jequié, Camaçari, Alagoinhas, Lauro de Freitas, Barreiras, Porto Seguro, Fortaleza, Caucaia, Juazeiro do Norte, Maracanaú, Sobral, Cariacica, Vila Velha, Serra, Vitória, Cachoeiro de Itapemirim, Colatina, Linhares, Goiânia, Anápolis, Luziânia, Rio Verde, Aparecida de Goiânia, Águas Lindas de Goiás, São Luís, Imperatriz, Caxias, Timon, Codo, Cuiabá, Várzea Grande, Rondonópolis, Campo Grande, Dourados, Belo Horizonte, Contagem, Betim, Ribeirão das Neves, Ibirité, Uberlândia, Juiz de Fora, Montes Claros, Uberaba, Governador Valadares, Ipatinga, Divinópolis, Sete Lagoas, Teófilo Otoni, Poços de Caldas, Patos de Minas, Barbacena, Sabará, Varginha, Santa Luzia, Belém, Abaetetuba, Ananindeua, Santarém, Marabá, Castanhal, Itaituba, João Pessoa, Campina Grande, Santa Rita, Curitiba, São José dos Pinhais, Londrina, Maringá, Ponta Grossa, Foz do Iguaçu, Cascavel, Colombo, Guarapuava, Paranaguá, Apucarana, Recife, Cabo
# * Ecuador:
# Quito, Guayaquil, Cuenca, Santo Domingo de los Colorados
# * Falkland Islands:
# Stanley
# * Algeria:
# Algiers, Annaba, Batna, Béchar, Sidi Bel Abbës, Skikda, Tébessa, Oran, Constantine, Sétif, Blida, Bejaïa, Mostaganem, Tlemcen, Tougourt, Ghardaïa, El Djelfa, Biskra, Laghouat, Tamanrasset
# * Libya:
# Tripoli, Benghazi, Misratah
# * Mali:
# Bamako, Gao, Kayes, Kidal, Koulikoro, Kalabancoro, Kati, Mopti, Ségou, Sikasso, Koutiala, Tombouctou
# * Mauritania:
# Atar, Kiffa, Aleg, Nouadhibou, Kaedi, Selibaby, Nema, Aioun, Akjoujt, Nouakchott, Tidjikja, Zouerate, Rosso
# * Morocco:
# Guelmim, Agadir, Kénitra, Settat, Marrakech, Oujda, Nador, Casablanca, Mohammedia, Rabat, Salé, Temara, Safi, Beni Mellal, Meknès, Fès, Al Hoceima, Tanger, Tétouan
# * Niger:
# Agadez, Diffa, Dosso, Maradi, Tessaoua, Aguié, Niamey, Tahoua, Birni-N'Konni, Illéla, Tillaberi, Zinder, Tanout, Magaria
# * Tunisia:
# Tunis, Sfax, Sousse
# * Western Sahara:
# El Aaiun
# * Angola:
# Cabinda, Mbanza Congo, Uige, Luanda, Ndalatando, Sumbe, Malanje, Lucapa, Saurimo, Benguela, Huambo, Bie, Luena, Menongue, Namibe, Lubango, Caxito, Ngiva
# * Congo:
# Dolisie, Sibiti, Madingou, Kinkala, Djambala, Owando, Ewo, Ouesso, Impfondo, Brazzaville, Pointe-Noire
# * Namibia:
# Windhoek
# * Zaire:
# Kikwit, Bandundu, Matadi, Boma, Mbandaka, Kisangani, Kananga, Tshikapa, Mbuji-Mayi, Mwene-Ditu, Lubumbashi, Kolwezi, Likasi, Kalemi, Kinshasa, Goma, Butembo, Bukavu, Uvira, Kindu
# * Zambia:
# Kabwe, Ndola, Kitwe, Chingola, Mufulira, Luanshya, Chipata, Mansa, Lusaka, Kasama, Solwezi, Livingstone, Mongu
# * Benin:
# Porto-Novo, Cotonou, Abomey-Calavi, Djougou
# * Burkina Faso:
# Ouagadougou, Bobo Dioulasso
# * Nigeria:
# Umuahia, Aba, Abuja, Yola, Uyo, Awka, Onitsha, Bauchi, Yenagoa, Makurdi, Maiduguri, Calabar, Asaba, Sapele, Warri, Abakaliki, Benin, Ado-Ekiti, Ilawe-Ekiti, Effon-Alaiye, Enugu, Gombe, Owerri, Dutse, Kaduna, Zaria, Kano, Katsina, Birnin Kebbi, Lokoja, Okene, Ilorin, Lagos, Ikorodu, Lafia, Minna, Bida, Abeokuta, Ijebu-Ode, Akure, Ondo, Owo, Ikare, Oshogbo, Ilesha, Ede, Ife, Ikire, Ibadan, Oyo, Ogbomosho, Iseyin, Jos, Port Harcourt, Sokoto, Jalingo, Damaturu, Gusau
# * Togo:
# Lomé
# * Botswana:
# Gaborone, Francistown
# * South Africa:
# Nelson Mandela Bay, Buffalo City, Bhisho, Mangaung, Tshwane, Johannesburg, Tembisa, Emfuleni, Ekurhuleni - Germiston, Msunduzi, eThekwini, Mbombela, Kimberley, Polokwane, Mmabatho, Cape Town
# * Zimbabwe:
# Harare, Bulawayo, Chitungwiza
# * Cote dIvoire:
# Agboville, Touba, San-Pedro, Odienne, Gagnoa, Daloa, Yamoussoukro, Abidjan, Bouafle, Man, Guiglo, Abengourou, Dimbokro, Korhogo, Divo, Aboisso, Bouaké, Seguela, Bondoukou
# * Ghana:
# Kumasi, Obuasi, Sunyani, Cape Coast, Koforidua, Accra, Tema, Ashiaman, Tamale, Bolgatanga, Wa, Ho, Sekondi, Takoradi
# * Burundi:
# Bujumbura
# * Rwanda:
# Kigali
# * Tanzania:
# Dodoma, Arusha, Moshi, Tanga, Morogoro, Dar es Salaam, Lindi, Mtwara, Songea, Iringa, Mbeya, Singida, Tabora, Sumbawanga, Kigoma-Ujiji, Shinyanga, Bukoba, Mwanza, Musoma, Mkokotoni, Koani, Zanzibar, Wete, Chake Chake, Babati, Njombe, Mpanda, Bariadi, Geita
# * Cameroon:
# Ngaoundéré, Yaoundé, Bertoua, Maroua, Douala, Garoua, Bamenda, Bafoussam, Ebolowa, Buea
# * Central African Republic:
# Bangui, Bimbo
# * Chad:
# N'Djamena
# * Equatorial Guinea:
# Malabo, Bata
# * Gabon:
# Libreville, Port-Gentil, Franceville
# * Cape Verde:
# Praia
# * Sudan:
# Nyala, Khartoum, Omdurman, Khartoum North, Al Ubayyiḑ, Kassala, Port Sudan, Al Gedaref, Al Gazira, Al Fashir
# * South Sudan:
# Juba
# * Comoros:
# Moroni
# * Guinea:
# Conakry, N'Zérékoré
# * Liberia:
# Monrovia
# * Djibouti:
# Djibouti
# * Eritrea:
# Asmara
# * Ethiopia:
# Addis Ababa, Aysaita, Bahir Dar, Gondar, Dessie, Asosa, Dire Dawa, Gambella, Harar, Finfine, Adama, Jimma, Bishoftu, Jijiga, Mekele, Hawassa
# * Somalia:
# Mogadishu
# * Kenya:
# Mombasa, Malindi, Machakos, Nairobi, Kisumu, Nakuru, Eldoret
# * Gambia:
# Banjul
# * Senegal:
# Dakar, Pikine, Guediawaye, Rufisque, Diourbel, Fatick, Kaolack, Kolda, Louga, Saint-Louis, Tambacounda, Thiès, M'Bour, Ziguinchor, Matam, Sedhiou, Kedougou, Kaffrine
# * Guinea-Bissau:
# Bissau
# * Sierra Leone:
# Freetown, Bo
# * Uganda:
# Kampala, Mbarara, Mukono
# * Lesotho:
# Maseru
# * Madagascar:
# Antsiranana, Antananarivo, Antsirabe, Fianarantsoa, Majunga, Tamatave, Toliara
# * Malawi:
# Lilongwe, Blantyre
# * Mozambique:
# Pemba, Xai-Xai, Inhambane, Chimoio, Nacala Porto, Matola, Nampula, Lichinga, Beira, Tete, Quelimane, Maputo
# * Mauritius:
# Port Louis
# * Mayotte:
# Mamoutzou
# * Swaziland:
# Mbabane
# * Reunion:
# Saint-Denis
# * Saint Helena:
# Jamestown
# * Sao Tome and Principe:
# São Tomé
# * Seychelles:
# Victoria
